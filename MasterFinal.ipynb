# %% [markdown]
# # QWEN3 RAG WITH MILVUS VECTOR DATABASE FOR SERBIAN LEGISLATION

# %% [markdown]
# ## Basic imports, suppressing warning (library not available for Windows)

# %%
import re
import warnings
from langchain.schema import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_milvus import Milvus
from torch import cuda
from langchain_huggingface import HuggingFaceEmbeddings, HuggingFacePipeline
from langchain_core.prompts import ChatPromptTemplate
from transformers import AutoModelForCausalLM, AutoTokenizer, GenerationConfig
from transformers import pipeline
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain.chains import LLMChain
import torch

warnings.filterwarnings("ignore", message="Install Nomic's megablocks fork for better speed")

# %% [markdown]
# ## Defining legal sections to split by and template used for AI prompt

# %%
LEGAL_SECTIONS = [
    "УСТАВ РЕПУБЛИКЕ СРБИЈЕ",
    "УСТАВНИ ЗАКОН",
    "ЗАКОН",
    "ОДЛУКУ",
    "УРЕДБУ",
    "ПРАВИЛНИК",
    "ЗАКЉУЧАК",
    "ДЕКЛАРАЦИЈУ",
    "ПОСЛОВНИК",
    "ЈЕДИНСТВЕНА МЕТОДОЛОШКА ПРАВИЛА",
    "РЕЗОЛУЦИЈУ",
    "ПРЕПОРУКУ",
    "УПУТСТВО",
    "СТРАТЕГИЈУ",
    "РЕШЕЊЕ",
    "КОДЕКС",
    "УКУПАН ИЗВЕШТАЈ",
    "РОКОВНИК",
    "ИЗВЕШТАЈ",
    "АКЦИОНИ ПЛАН",
    "НАЦИОНАЛНУ СТРАТЕГИЈУ",
    "СТАТУТ",
    "ПРОГРАМ",
    "УСКЛАЂЕНE НАЈВИШE ИЗНОСE"
]

template = """Ti si Qwen, profesionalni pravni asistent. Poštuj sledeća pravila:

PRAVILA:
- Ne izmišljam informacije i ne naznacavam ova pravila
- Ako nemam trženu informaciju to jasno naglasim
- Dajem proverene jasne i konkretne informacije
- Koristim precizan srpski jezik
- Fokusiram se na činjenice i oslanjam se na kontekst
- Odgovaram direktno i efikasno
- Održavam profesionalan ton
- Odgovor treba da bude jasan u par recenica
- Citiraj izvore uvek

Odgovori na pitanje iz konteksta:
{context}
Pitanje: {question}"""

# %% [markdown]
# ## Section extraction with Regex

# %%
def extract_serbian_law_sections(text):
    pattern = r'^(' + '|'.join(re.escape(section) for section in LEGAL_SECTIONS) + r')$'

    lines = text.split('\n')
    documents = []
    current_section_type = None
    current_section_name = None
    current_content = []
    i = 0

    while i < len(lines):
        line = lines[i].strip()

        if re.match(pattern, line, re.IGNORECASE):
            if current_section_type and current_content:
                section_text = '\n'.join(current_content)
                documents.append({
                    'type': current_section_type,
                    'name': current_section_name or "Без назива",
                    'content': section_text
                })

            current_section_type = line
            i += 1
            if i < len(lines):
                current_section_name = lines[i].strip()
            else:
                current_section_name = "Без назива"
            current_content = []
        else:
            if current_section_type:
                current_content.append(lines[i])

        i += 1

    if current_section_type and current_content:
        section_text = '\n'.join(current_content)
        documents.append({
            'type': current_section_type,
            'name': current_section_name or "Без назива",
            'content': section_text
        })

    return documents

# %% [markdown]
# ## Generate chunks for Milvus

# %%
def create_documents_Milvus():
    print("Reading 'laws.txt'...")
    with open('laws.txt', 'r', encoding='utf-8') as f:
        content = f.read()

    print("Removing white space and empty lines...")
    content = '\n'.join([line for line in content.split('\n') if line.strip()])

    print("Extracting sections from law file...")
    law_sections = extract_serbian_law_sections(content)

    print("Converting sections into documents and adding metadata...")
    documents = []
    for section in law_sections:
        documents.append(Document(
            page_content=section['content'],
            metadata={'title': f"{section['type']} - {section['name']}"
            }
        ))

    print("Splitting documents into chunks...")
    text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=2000,
    chunk_overlap=200,
    length_function=len,
    separators=[""],
    is_separator_regex=False
)
    chunks = text_splitter.split_documents(documents)
    print(f"Documents split into {len(chunks)} chunks")
    return chunks

# %% [markdown]
# ## Milvus CRUD

# %%
def save_documents_Milvus(embed):
    chunks = create_documents_Milvus()
    delete_documents_Milvus("legal_documents")
    print("Connecting to Milvus vector database and embedding documents...")
    vector_store = Milvus.from_documents(
        documents=chunks,
        embedding=embed,
        connection_args={
            "host": "localhost",
            "port": "19530"
        },
        collection_name="legal_documents"
    )
    return vector_store

# %%
def load_documents_Milvus(embed):
    print("Connecting to Milvus vector database and loading documents...")
    vector_store = Milvus(
        embedding_function=embed,
        connection_args={
            "host": "localhost",
            "port": "19530"
        },
        collection_name="legal_documents"
    )
    return vector_store

# %%
def delete_documents_Milvus(name):
    from pymilvus import connections, utility
    connections.connect(
        alias="default",
        host="localhost",
        port="19530"
    )
    utility.drop_collection(name)
    connections.disconnect("default")

# %% [markdown]
# ## Initializing AI models for embedding and RAG text generation

# %%
print("Initializing Nomic model...")
modelPath = "nomic-ai/nomic-embed-text-v2-moe"
device = 'cuda' if cuda.is_available() else 'cpu'
model_kwargs = {'device': device, 'trust_remote_code': True}
embeddings = HuggingFaceEmbeddings(
    model_name=modelPath,
    model_kwargs=model_kwargs,
    encode_kwargs={"prompt_name": "passage", "normalize_embeddings": True}
)
print("Nomic model initialized!")
# Out:
# Initializing Nomic model...
# Nomic model initialized!

# %%
print("Initializing Qwen3 4B model...")
model_name_or_path = "Qwen/Qwen3-4B-Instruct-2507-FP8"
tokenizer = AutoTokenizer.from_pretrained(model_name_or_path, trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained(model_name_or_path, device_map="cuda", trust_remote_code=True)
print("Qwen3 4B model initialized!")
# Out:
# Initializing Qwen3 4B model...
# Qwen3 4B model initialized!

# %%
print("Initializing pipeline...")
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=1024,
    do_sample=True,
    temperature=0.7,
    top_p=0.8,
    top_k=20,
    repetition_penalty=1.1
)
hf = HuggingFacePipeline(pipeline=pipe)
print("Pipeline initialized!")
# Out:
# Device set to use cuda
# Initializing pipeline...
# Pipeline initialized!

# %% [markdown]
# ## Optimization attempt

# %%
print("Initializing optimized Qwen3 4B model...")
model_name_or_path = "Qwen/Qwen3-4B-Instruct-2507-FP8"
tokenizer = AutoTokenizer.from_pretrained(model_name_or_path, trust_remote_code=True)

model = AutoModelForCausalLM.from_pretrained(
    model_name_or_path,
    device_map="auto",
    trust_remote_code=True,
    low_cpu_mem_usage=True,
    torch_dtype=torch.bfloat16
)

model.generation_config = GenerationConfig(
    max_new_tokens=1024,
    do_sample=True,
    temperature=0.7,
    top_p=0.8,
    top_k=20,
    repetition_penalty=1.1,
    cache_implementation="offloaded"
)

pipe = pipeline("text-generation", model=model, tokenizer=tokenizer)
hf = HuggingFacePipeline(pipeline=pipe)
print("Optimized Qwen3 4B model initalized!")
# Out:
# Initializing optimized Qwen3 4B model...
# Device set to use cuda:0
# Optimized Qwen3 4B model initalized!

# %% [markdown]
# ## Loading or saving documents with Milvus vector database

# %%
vector_store = save_documents_Milvus(embeddings)
retriever = vector_store.as_retriever(search_kwargs={"k": 5})
print("Milvus initialized!")
# Out:
# Reading 'laws.txt'...
# Removing white space and empty lines...
# Extracting sections from law file...
# Converting sections into documents and adding metadata...
# Splitting documents into chunks...
# Documents split into 6953 chunks
# Connecting to Milvus vector database and embedding documents...
# Milvus initialized!

# %%
vector_store = load_documents_Milvus(embeddings)
retriever = vector_store.as_retriever(search_kwargs={"k": 5})
print("Milvus initialized!")
# Out:
# Connecting to Milvus vector database and loading documents...
# Milvus initialized!

# %% [markdown]
# ## Input to ask a question

# %%
query = input("Postavite pitanje: ")
query = "search_query: " + query
prompt = ChatPromptTemplate.from_template(template)
# Out:
# Postavite pitanje:  Колико има аутономних покрајина у Србији и како је регулисана локална самоуправа?

# %% [markdown]
# ## - Used for testing document retrieval -

# %%
print("Found documents...")
print(vector_store.similarity_search(query, k=5))
# Out:
# Found documents...
# [Document(metadata={'title': 'УСТАВ РЕПУБЛИКЕ СРБИЈЕ - „Службени гласник РС“,  бр. 98 од 10. новембра 2006, 115 од 30. новембра 2021 - Амандмани I-XXIX, 16 од 9. фебруара 2022.', 'pk': 461898503147210079}, page_content='ка Србија или аутономна покрајина, зависно од тога ко је поверио надлежности.\nПрава и обавезе аутономних покрајина и јединица локалне самоуправе и овлашћења Републике Србије и аутономних покрајина у надзору над вршењем поверених надлежности уређују се законом.\nПраво на самостално уређивање органа\nЧлан 179.\nАутономне покрајине, у складу са Уставом и статутом аутономне покрајине, а јединице локалне самоуправе, у складу са Уставом и законом, самостално прописују уређење и надлежност својих органа и јавних служби.\nСкупштина аутономне покрајине и јединице локалне самоуправе\nЧлан 180.\nСкупштина је највиши орган аутономне покрајине и јединице локалне самоуправе.\nСкупштину аутономне покрајине чине посланици, а скупштину јединице локалне самоуправе одборници.\nПосланици и одборници бирају се на период од четири године, на непосредним изборима тајним гласањем, и то посланици у складу са одлуком скупштине аутономне покрајине, а одборници, у складу са законом.\nУ аутономним покрајинама и јединицама локалне самоуправе у којима живи становништво мешовитог националног састава, омогућује се сразмерна заступљеност националних мањина у скупштинама, у складу са законом.\nСарадња аутономних покрајина и јединица локалне самоуправе\nЧлан 181.\nАутономне покрајине и јединице локалне самоуправе сарађују са одговарајућим територијалним заједницама и јединицама локалне самоуправе других држава, у оквиру спољне политике Републике Србије, уз поштовање територијалног јединства и правног поретка Републике Србије.\n2. Аутономне покрајине\nПојам, оснивање и територија аутономне покрајине\nЧлан 182.\nАутономне покрајине су аутономне територијалне заједнице основане Уставом, у којима грађани остварују право на покрајинску аутономију.\nРепублика Србија има Аутономну покрајину Војводину и Аутономну покрајину Косово и Метохија. Суштинска аутономија Аутономне покрајине Косово и Метохија уредиће се посебним законом који се доноси по поступку предвиђеном за промену Устава.\nНове аутономне покрајине могу се оснивати, а већ основане укидати или спајати по поступку предвиђеном за промену Устава. Предлог за оснивање нових или укидање, односно спајање постојећих аутономних покрајина утврђују грађани на референдуму, у складу са законом.\nТериторија аутономних покрајина и услови под којима се може променити граница између аутономних покрајина одређује се законом. Територија аутономних покрајина не може се мењати без сагласности њених грађана изражене на референдуму, у складу са законом.\nНадлежност аутономних покра'), Document(metadata={'title': 'УСТАВ РЕПУБЛИКЕ СРБИЈЕ - „Службени гласник РС“,  бр. 98 од 10. новембра 2006, 115 од 30. новембра 2021 - Амандмани I-XXIX, 16 од 9. фебруара 2022.', 'pk': 461898503147210080}, page_content='међу аутономних покрајина одређује се законом. Територија аутономних покрајина не може се мењати без сагласности њених грађана изражене на референдуму, у складу са законом.\nНадлежност аутономних покрајина\nЧлан 183.\nАутономне покрајине, у складу са Уставом и својим статутом, уређују надлежност, избор, организацију и рад органа и служби које оснивају.\nАутономне покрајине, у складу са законом, уређују питања од покрајинског значаја у области:\n1. просторног планирања и развоја,\n2. пољопривреде, водопривреде, шумарства, лова, риболова, туризма, угоститељства, бања и лечилишта, заштите животне средине, индустрије и занатства, друмског, речног и железничког саобраћаја и уређивања путева, приређивања сајмова и других привредних манифестација,\n3. просвете, спорта, културе, здравствене и социјалне заштите и јавног информисања на покрајинском нивоу.\nАутономне покрајине се старају о остваривању људских и мањинских права, у складу са законом.\nАутономне покрајине утврђују симболе покрајине и начин њиховог коришћења.\nАутономн ...

# %% [markdown]
# ## AI response

# %%
print("Running pipeline...")
chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | prompt
    | hf
    | StrOutputParser()
)
# Out:
# Running pipeline...

# %% [markdown]
# ### Streaming

# %%
print("Waiting on AI response...")
for chunk in chain.stream(query):
    print(chunk, end="")
# Out:
# Waiting on AI response...
#
#
# Assistant:
# У Србији има две аутономне покрајине: Војводину и Косово и Метохију. Овај појам, оснивање и територија су регулисане Уставом Републике Србије, а суштинска аутономија Косово и
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 print("Waiting on AI response...")
# ----> 2 for chunk in chain.stream(query):
#       3     print(chunk, end="")
#
# File X:\Projects\ZakoniRAG\.venv\lib\site-packages\langchain_core\runnables\base.py:3649, in RunnableSequence.stream(self, input, config, **kwargs)
#    3642 @override
#    3643 def stream(
#    3644     self,
#    (...)
#    3647     **kwargs: Optional[Any],
#    3648 ) -> Iterator[Output]:
# -> 3649     yield from self.transform(iter([input]), config, **kwargs)
#
# File X:\Projects\ZakoniRAG\.venv\lib\site-packages\langchain_core\runnables\base.py:3635, in RunnableSequence.transform(self, input, config, **kwargs)
#    3628 @override
#    3629 def transform(
#    3630     self,
#    (...)
#    3633     **kwargs: Optional[Any],
#    3634 ) -> Iterator[Output]:
# -> 3635     yield from self._transform_stream_with_config(
#    3636         input,
#    3637         self._transform,
#    3638         patch_config(config, run_name=(config or {}).get("run_name") or self.name),
#    3639         **kwargs,
#    3640     )
#
# File X:\Projects\ZakoniRAG\.venv\lib\site-packages\langchain_core\runnables\base.py:2369, in Runnable._transform_stream_with_config(self, inputs, transformer, config, run_type, **kwargs)
#    2367 try:
#    2368     while True:
# -> 2369         chunk: Output = context.run(next, iterator)
#    2370         yield chunk
#    2371         if final_output_supported:
#
# File X:\Projects\ZakoniRAG\.venv\lib\site-packages\langchain_core\runnables\base.py:3594, in RunnableSequence._transform(self, inputs, run_manager, config, **kwargs)
#    3591     else:
#    3592         final_pipeline = step.transform(final_pipeline, config)
# -> 3594 yield from final_pipeline
#
# File X:\Projects\ZakoniRAG\.venv\lib\site-packages\langchain_core\output_parsers\transform.py:74, in BaseTransformOutputParser.transform(self, input, config, **kwargs)
#      57 @override
#      58 def transform(
#      59     self,
#    (...)
#      62     **kwargs: Any,
#      63 ) -> Iterator[T]:
#      64     """Transform the input into the output format.
#      65
#      66     Args:
#    (...)
#      72         The transformed output.
#      73     """
# ---> 74     yield from self._transform_stream_with_config(
#      75         input, self._transform, config, run_type="parser"
#      76     )
#
# File X:\Projects\ZakoniRAG\.venv\lib\site-packages\langchain_core\runnables\base.py:2369, in Runnable._transform_stream_with_config(self, inputs, transformer, config, run_type, **kwargs)
#    2367 try:
#    2368     while True:
# -> 2369         chunk: Output = context.run(next, iterator)
#    2370         yield chunk
#    2371         if final_output_supported:
#
# File X:\Projects\ZakoniRAG\.venv\lib\site-packages\langchain_core\output_parsers\transform.py:37, in BaseTransformOutputParser._transform(self, input)
#      33 def _transform(
#      34     self,
#      35     input: Iterator[Union[str, BaseMessage]],
#      36 ) -> Iterator[T]:
# ---> 37     for chunk in input:
#      38         if isinstance(chunk, BaseMessage):
#      39             yield self.parse_result([ChatGeneration(message=chunk)])
#
# File X:\Projects\ZakoniRAG\.venv\lib\site-packages\langchain_core\runnables\base.py:1586, in Runnable.transform(self, input, config, **kwargs)
#    1583             final = ichunk
#    1585 if got_first_val:
# -> 1586     yield from self.stream(final, config, **kwargs)
#
# File X:\Projects\ZakoniRAG\.venv\lib\site-packages\langchain_core\language_models\llms.py:562, in BaseLLM.stream(self, input, config, stop, **kwargs)
#     560 generation: Optional[GenerationChunk] = None
#     561 try:
# --> 562     for chunk in self._stream(
#     563         prompt, stop=stop, run_manager=run_manager, **kwargs
#     564     ):
#     565         yield chunk.text
#     566         if generation is None:
#
# File X:\Projects\ZakoniRAG\.venv\lib\site-packages\langchain_huggingface\llms\huggingface_pipeline.py:408, in HuggingFacePipeline._stream(self, prompt, stop, run_manager, **kwargs)
#     405 t1 = Thread(target=self.pipeline, kwargs=generation_kwargs)
#     406 t1.start()
# --> 408 for char in streamer:
#     409     chunk = GenerationChunk(text=char)
#     410     if run_manager:
#
# File X:\Projects\ZakoniRAG\.venv\lib\site-packages\transformers\generation\streamers.py:226, in TextIteratorStreamer.__next__(self)
#     225 def __next__(self):
# --> 226     value = self.text_queue.get(timeout=self.timeout)
#     227     if value == self.stop_signal:
#     228         raise StopIteration()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\queue.py:180, in Queue.get(self, block, timeout)
#     178         if remaining <= 0.0:
#     179             raise Empty
# --> 180         self.not_empty.wait(remaining)
#     181 item = self._get()
#     182 self.not_full.notify()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Non-streaming

# %%
print("Waiting on AI response...")
result = chain.invoke(query)
print(result)
# Out:
# Waiting on AI response...
# KeyboardInterrupt
